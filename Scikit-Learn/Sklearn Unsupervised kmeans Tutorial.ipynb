# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Create custom data

# %%
from sklearn.datasets import make_blobs

# %%
# Create Data
data, cluster_number = make_blobs(n_samples=200, n_features=2, centers=4, cluster_std=2,random_state=6)

# %%
plt.scatter(data[:,0],data[:,1],c=cluster_number,cmap='rainbow')

# %%
data[:5]
# Out:
# array([[-6.86630367, -0.99001908],
#        [ 8.07945936, -3.1021014 ],
#        [11.10265092, -9.79271322],
#        [-1.22826203,  0.85957055],
#        [ 7.64837129, -9.70575561]])

# %%
cluster_number
# Out:
# array([2, 0, 1, 3, 1, 1, 3, 1, 3, 3, 2, 0, 0, 3, 2, 1, 1, 0, 1, 3, 1, 3,
#        0, 2, 0, 3, 3, 3, 2, 2, 1, 3, 0, 1, 2, 1, 3, 3, 1, 0, 3, 1, 3, 2,
#        0, 3, 3, 0, 2, 0, 2, 0, 3, 1, 1, 0, 3, 2, 2, 2, 3, 0, 0, 3, 2, 0,
#        3, 1, 0, 0, 2, 2, 2, 2, 3, 2, 2, 3, 2, 1, 0, 3, 2, 0, 1, 2, 0, 1,
#        3, 1, 1, 3, 2, 3, 3, 3, 3, 0, 1, 1, 3, 3, 1, 0, 3, 2, 0, 2, 2, 2,
#        1, 0, 3, 1, 1, 2, 2, 0, 0, 1, 2, 2, 0, 1, 0, 1, 2, 1, 2, 3, 3, 1,
#        1, 1, 1, 3, 1, 1, 3, 2, 2, 3, 2, 2, 2, 0, 0, 1, 3, 1, 1, 3, 0, 1,
#        2, 1, 1, 0, 0, 3, 0, 0, 2, 0, 1, 1, 2, 1, 0, 2, 3, 3, 0, 3, 0, 0,
#        3, 0, 0, 2, 0, 0, 1, 0, 0, 2, 2, 2, 1, 0, 1, 0, 2, 3, 0, 3, 2, 3,
#        2, 1])

# %% [markdown]
# # Plot the data

# %%
plt.scatter(data[:,0],data[:,1],c=cluster_number,cmap='rainbow')

# %% [markdown]
# # Kmeans parameters
# **n_clusters : int, optional, default: 8**
#
#     The number of clusters to form as well as the number of
#     centroids to generate.
#
# **init : {'k-means++', 'random' or an ndarray}
#     Method for initialization, defaults to 'k-means++':**
#
#     'k-means++' : selects initial cluster centers for k-mean
#     clustering in a smart way to speed up convergence.
#
#     'random': choose k observations (rows) at random from data for
#     the initial centroids.
#
#     If an ndarray is passed, it should be of shape (n_clusters, n_features)
#     and gives the initial centers.
#
# **max_iter : int, default: 300**
#
#     Maximum number of iterations of the k-means algorithm for a
#     single run.

# %% [markdown]
# # Instantiate the model

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4)

# %%
kmeans.fit(data)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# ### The cluster centroids coordinates

# %%
kmeans.cluster_centers_
# Out:
# array([[ 0.67109768, -1.68106528],
#        [ 6.27791186, -9.21655659],
#        [-7.80657238,  2.31532079],
#        [ 8.49662227, -3.28520813]])

# %% [markdown]
# ### Number of iterations run to converge

# %%
kmeans.n_iter_
# Out:
# 4

# %% [markdown]
# ### Sum of squared distances of samples to their closest cluster center (SSE).

# %%
kmeans.inertia_
# Out:
# 1404.8864074540625

# %% [markdown]
# ### Clusters assigned to each data point

# %%
cluster_pred = kmeans.predict(data)

# %%
cluster_pred
# Out:
# array([2, 3, 1, 0, 1, 1, 0, 1, 0, 0, 0, 3, 3, 0, 2, 1, 1, 0, 1, 0, 1, 0,
#        3, 2, 3, 0, 0, 0, 2, 2, 1, 0, 3, 1, 2, 1, 0, 0, 1, 3, 0, 1, 0, 2,
#        3, 0, 0, 3, 2, 3, 2, 3, 0, 1, 1, 0, 0, 2, 2, 2, 0, 3, 1, 0, 2, 3,
#        0, 1, 3, 3, 2, 2, 2, 2, 0, 2, 2, 0, 2, 1, 3, 0, 2, 3, 1, 2, 3, 1,
#        0, 1, 1, 0, 2, 0, 0, 0, 0, 3, 1, 1, 0, 1, 1, 3, 0, 2, 0, 2, 2, 2,
#        1, 3, 0, 1, 1, 2, 2, 3, 3, 1, 2, 2, 3, 1, 3, 1, 2, 0, 2, 0, 0, 1,
#        1, 1, 1, 0, 1, 1, 0, 2, 2, 0, 2, 2, 2, 3, 3, 1, 0, 1, 1, 0, 3, 1,
#        2, 1, 1, 3, 0, 0, 3, 3, 2, 3, 1, 3, 2, 3, 3, 2, 0, 0, 3, 0, 3, 3,
#        0, 3, 3, 2, 3, 3, 1, 3, 3, 2, 2, 2, 1, 3, 1, 3, 2, 1, 3, 0, 2, 0,
#        2, 1])

# %%
plt.scatter(data[:,0],data[:,1],c=cluster_pred,cmap='rainbow')

# %% [markdown]
# # A bad beginning
# Let's choose bad cluster centroids in the beginning

# %%
init_array = np.array([[0,0], [5,0],[-15,0], [-15,10]])

# %%
kmeans_bad = KMeans(n_clusters=4, init=init_array ,max_iter=4, n_init=1)

# %%
kmeans_bad.fit(data)
# Out:
# KMeans(algorithm='auto', copy_x=True,
#        init=array([[  0,   0],
#        [  5,   0],
#        [-15,   0],
#        [-15,  10]]),
#        max_iter=4, n_clusters=4, n_init=1, n_jobs=None,
#        precompute_distances='auto', random_state=None, tol=0.0001, verbose=0)

# %%
bad_pred = kmeans_bad.predict(data)

# %%
plt.scatter(data[:,0],data[:,1],c=bad_pred,cmap='tab20')
plt.scatter(init_array[:,0], init_array[:, 1], marker='+', c='g')
plt.scatter(kmeans_bad.cluster_centers_[:, 0], kmeans_bad.cluster_centers_[:, 1], c='k' ,marker='o')

# %% [markdown]
# # Changing n_clusters

# %%
kmeans3 = KMeans(n_clusters=3)

# %%
kmeans3.fit(data)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
cluster3_pred = kmeans3.predict(data)

# %%
plt.scatter(data[:,0],data[:,1],c=cluster3_pred,cmap='rainbow')

# %% [markdown]
# # The Elbow method
# When you plot SSE as a function of the number of clusters, notice that SSE continues to decrease as you increase k. As more centroids are added, the distance from each point to its closest centroid will decrease. This is because the samples will be closer to the centroids they are assigned to.<br>
# The x-value of the elbow point is thought to be a reasonable trade-off between error and number of clusters.

# %%
sse = []
for k in range(1, 11):
    km = KMeans(n_clusters=k, init='random',random_state=0)
    km.fit(data)
    sse.append(km.inertia_)

# plot
plt.plot(range(1, 11), sse, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.show()

# %%
kmeans = KMeans(n_clusters=4)

# %%
kmeans.fit(data)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans_clusters = kmeans.predict(data)

# %%
plt.scatter(data[:,0],data[:,1],c=kmeans_clusters,cmap='coolwarm')
plt.title('KMeans clusters')
# Out:
# Text(0.5, 1.0, 'KMeans clusters')

# %%
plt.scatter(data[:,0],data[:,1],c=cluster_number,cmap='rainbow')
plt.title('Original data clusters')
# Out:
# Text(0.5, 1.0, 'Original data clusters')
